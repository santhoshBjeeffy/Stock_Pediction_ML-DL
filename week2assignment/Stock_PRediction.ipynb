# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/19O4w8F-wQ3BqszS0K6Dn2GCG_Z4SLiIO)
#
# In this notebook, we will explore stock price prediction using three methods:
#
# * Linear Regression using $L_2$ regularization or Ridge Regression
# * Gradient Boosting Regressors
# * Neural Network based approaches using 1D Convolutions, LSTM layers with a Huber loss
#
# The source of the stock prices is from https://finance.yahoo.com/quote/TSLA/history?p=TSLA where I downloaded all of the stock prices for Tesla Inc. since they become a publicly traded company up until today's date (September 1st, 2019).  The variable to predict is the **Adjusted Close** price.
#
# If you are running this on Google Colab, please make sure you switch the runtime to GPU so when you run the cells using neural networks, it will train much faster.

# %% [markdown]
# First let's import all of the necessary packages we need, which include NumPy, Pandas, Matplotlib, Scikit-learn and Keras/Tensorflow.

# %%
# Import necessary packages
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import sklearn
from sklearn.linear_model import Ridge
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Conv1D, LSTM, Dense
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.losses import Huber
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %% [markdown]
# I have exported the Tesla stock price data to my personal Dropbox and will be downloading it locally.

# %%
# Download the data and store it
# Tesla stock since the beginning
# !wget -O tesla.csv https://www.dropbox.com/s/na2vurooejpew59/TSLA.csv?dl=1
# Out:
# --2019-09-07 03:48:41--  https://www.dropbox.com/s/na2vurooejpew59/TSLA.csv?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.1, 2620:100:601b:1::a27d:801
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/na2vurooejpew59/TSLA.csv [following]
# --2019-09-07 03:48:41--  https://www.dropbox.com/s/dl/na2vurooejpew59/TSLA.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc71df408fffa09623bb8ed94371.dl.dropboxusercontent.com/cd/0/get/AoFqrd7X48BYhY1rbj9zRmBfJGWKKm-5wb8No9IO2heiM39xPkqETkVhzgajm2XQmMx0nwV3LATIfOGsLZMbzDRMLBiP5gfIarjGRm_kVv0h1YFMxCUSFPY6mEq592UhfjI/file?dl=1# [following]
# --2019-09-07 03:48:42--  https://uc71df408fffa09623bb8ed94371.dl.dropboxusercontent.com/cd/0/get/AoFqrd7X48BYhY1rbj9zRmBfJGWKKm-5wb8No9IO2heiM39xPkqETkVhzgajm2XQmMx0nwV3LATIfOGsLZMbzDRMLBiP5gfIarjGRm_kVv0h1YFMxCUSFPY6mEq592UhfjI/file?dl=1
# Resolving uc71df408fffa09623bb8ed94371.dl.dropboxusercontent.com (uc71df408fffa09623bb8ed94371.dl.dropboxusercontent.com)... 162.125.8.6, 2620:100:6018:6::a27d:306
# Connecting to uc71df408fffa09623bb8ed94371.dl.dropboxusercontent.com (uc71df408fffa09623bb8ed94371.dl.dropboxusercontent.com)|162.125.8.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 167196 (163K) [application/binary]
# Saving to: ‘tesla.csv’
#
# tesla.csv           100%[===================>] 163.28K  --.-KB/s    in 0.05s
#
# 2019-09-07 03:48:42 (3.31 MB/s) - ‘tesla.csv’ saved [167196/167196]

# %% [markdown]
# Use Pandas to read in the data and set the independent variable to be the *Date*.  Let's also take a look at the first few entries

# %%
df = pd.read_csv('tesla.csv')

# %%
df.set_index('Date', inplace=True)
df.head()
# Out:
#                  Open   High        Low      Close  Adj Close    Volume
# Date
# 2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %% [markdown]
# Let's take a look at how the prices looks like each day since the beginning up to this point with the date on the x-axis and the price on the y-axis.

# %%
df['Adj Close'].plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# To make this more robust to noise and to leverage past values, we will not use the date to predict the stock prices, but we will use batches of 32 prices where each training example, we leverage 32 prices from the past to predict the price on the 33rd day.  We will thus have $N - 32$ training examples with $N$ being the number of days we've downloaded for the stock data.  We will thus create a 2D matrix of training samples with each row being the prices 32 consecutive days in the past with the price to predict being the current day.

# %%
window_size = 32 # Allow us to look at 32 days into the past
# Prepare the data so that we have 32 day windows and predict what the next day should be

# Get indices of access for the data
num_samples = len(df) - window_size
indices = np.arange(num_samples).astype(np.int)[:,None] + np.arange(window_size + 1).astype(np.int)

# %%
data = df['Adj Close'].values[indices] # Create the 2D matrix of training samples

# %% [markdown]
# We create a 2D matrix such that we have 33 columns per example.  The training samples will be the first 32 columns with the target variable being the last column.

# %%
X = data[:,:-1] # Each row represents 32 days in the past
y = data[:,-1] # Each output value represents the 33rd day

# %% [markdown]
# Perform train/test split such that the first 80% of the prices is the training set and the last 20% of the prices is the test dataset.  We will train on the training set and test the performance on the test set to see how well we can forecast the price for Tesla stock.

# %%
# Train and test split
split_fraction = 0.8
ind_split = int(split_fraction * num_samples)
X_train = X[:ind_split]
y_train = y[:ind_split]
X_test = X[ind_split:]
y_test = y[ind_split:]

# %% [markdown]
# # Method #1 - Ridge Regression
#
# We will use the Ridge Regression method from Scikit-learn where we'll train and perform inference on the training and test data respectively.  Let's also plot how it compares with the actual data for both training and test.

# %%
# Train
ridge_model = Ridge()
ridge_model.fit(X_train, y_train)

# Infer
y_pred_train_ridge = ridge_model.predict(X_train)
y_pred_ridge = ridge_model.predict(X_test)

# %%
# Plot what it looks like for the training data
df_ridge = df.copy()
df_ridge.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_ridge = df_ridge.iloc[window_size:ind_split] # Past 32 days we don't know yet
df_ridge['Adj Close Train'] = y_pred_train_ridge[:-window_size]
df_ridge.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# OK... not bad and very frighteningly close.  We may be overfitting.  Let's check out the test data.

# %%
# Same for the test
df_ridge = df.copy()
df_ridge.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_ridge = df_ridge.iloc[ind_split+window_size:] # Past 32 days we don't know yet
df_ridge['Adj Close Test'] = y_pred_ridge
df_ridge.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# Wow... ok let's move on.
#
# # Method #2 - Gradient Boosting Trees
#
# Let's apply the same methodology from Method #1 to Gradient Boosting Trees in Scikit-learn.

# %%
# Model #2 - Gradient Boosting Trees
gb_model = GradientBoostingRegressor()
gb_model.fit(X_train, y_train)

# Infer
y_pred_train_gb = gb_model.predict(X_train)
y_pred_gb = gb_model.predict(X_test)

# %%
# Plot what it looks like for the training data
df_gb = df.copy()
df_gb.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_gb = df_gb.iloc[window_size:ind_split] # Past 32 days we don't know yet
df_gb['Adj Close Train'] = y_pred_train_gb[:-window_size]
df_gb.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# Again... frighteningly similar.  Let's check the test data.

# %%
# Same for the test
df_gb = df.copy()
df_gb.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_gb = df_gb.iloc[ind_split+window_size:] # Past 32 days we don't know yet
df_gb['Adj Close Test'] = y_pred_gb
df_gb.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# The results here make sense.  Since trees performing majority voting so there's no interpolation involved, we can see at points of high curvature, it doesn't do so well but the general trend is correct.
#
# # Method #3 - Using neural networks with 1D convolutional and LSTM layers
#
# The last method we'll use is a neural network based one using Keras / Tensorflow.  We use a stack of Conv1D and LSTM layers, followed by Dense layers lastly followed by a linear layer to predict the stock price.

# %%
# Model #3 - Using RNNs
keras_model = Sequential([
  Conv1D(filters=128, kernel_size=5, input_shape=(window_size, 1), strides=1, padding="causal", activation="tanh"),
  Conv1D(filters=128, kernel_size=5, strides=1, padding="causal", activation="tanh"),
  LSTM(128, return_sequences=True),
  LSTM(128),
  Dense(64, activation="tanh"),
  Dense(64, activation="tanh"),
  Dense(1)
])

keras_model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 32, 128)           768
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 32, 128)           82048
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32, 128)           131584
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 358,465
# Trainable params: 358,465
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# This is a technique to find the optimal learning rate for the neural network.  Specifically we gradually increase the learning rate at each epoch, recording the loss for each then choosing the learning rate that has the smallest loss overall.
#
# Also, neural networks learn better when the data is normalized so we will normalize the data to the $[-1,1]$ range by using Scikit-learn's `MinMaxScaler`.  Therefore, we need to find apply this scaling on all of the price data, then decompose it into the training and test sets again.

# %%
# First figure out the right learning rate
lr_schedule = LearningRateScheduler(lambda epoch: 1e-8 * 10**(epoch / 20)) # 10*0.00000001 power (epoch/20)
optimizer = SGD(lr=1e-8, momentum=0.9)
keras_model.compile(loss=Huber(),
                    optimizer=optimizer,
                    metrics=["mae"])
# Scale the data due to LSTM units
scaler = MinMaxScaler(feature_range=(-1, 1))
data_transform = scaler.fit_transform(df['Adj Close'].values[:,None])
data_transform = data_transform[indices]
X2 = data_transform[:,:-1]
y2 = data_transform[:,-1]
X_train_reshape = X2[:ind_split]
y_train_reshape = y2[:ind_split]
X_test_reshape = X2[ind_split:]
y_test_reshape = y2[ind_split:]
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# We now try and find the optimal learning rate.  If you're using Google Colab, this will take ~4 minutes.

# %%
history = keras_model.fit(X_train_reshape, y_train_reshape, batch_size=256, epochs=250, callbacks=[lr_schedule], validation_data=(X_test_reshape, y_test_reshape))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 1822 samples, validate on 456 samples
# Epoch 1/250
# 1822/1822 [==============================] - 7s 4ms/step - loss: 0.1996 - mean_absolute_error: 0.5108 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 2/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1996 - mean_absolute_error: 0.5108 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 3/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1996 - mean_absolute_error: 0.5108 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 4/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1996 - mean_absolute_error: 0.5108 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 5/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1996 - mean_absolute_error: 0.5108 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 6/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1996 - mean_absolute_error: 0.5108 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 7/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1996 - mean_absolute_error: 0.5108 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 8/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1996 - mean_absolute_error: 0.5108 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 9/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1996 - mean_absolute_error: 0.5108 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 10/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1996 - mean_absolute_error: 0.5108 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 11/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1996 - mean_absolute_error: 0.5108 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 12/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1996 - mean_absolute_error: 0.5107 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 13/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1996 - mean_absolute_error: 0.5107 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 14/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1996 - mean_absolute_error: 0.5107 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 15/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1996 - mean_absolute_error: 0.5107 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 16/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1996 - mean_absolute_error: 0.5107 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 17/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1996 - mean_absolute_error: 0.5107 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 18/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1995 - mean_absolute_error: 0.5107 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 19/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1995 - mean_absolute_error: 0.5107 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 20/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1995 - mean_absolute_error: 0.5107 - val_loss: 0.1600 - val_mean_absolute_error: 0.5172
# Epoch 21/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1995 - mean_absolute_error: 0.5107 - val_loss: 0.1601 - val_mean_absolute_error: 0.5173
# Epoch 22/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1995 - mean_absolute_error: 0.5107 - val_loss: 0.1601 - val_mean_absolute_error: 0.5173
# Epoch 23/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1995 - mean_absolute_error: 0.5107 - val_loss: 0.1601 - val_mean_absolute_error: 0.5173
# Epoch 24/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1995 - mean_absolute_error: 0.5107 - val_loss: 0.1601 - val_mean_absolute_error: 0.5173
# Epoch 25/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1995 - mean_absolute_error: 0.5106 - val_loss: 0.1601 - val_mean_absolute_error: 0.5173
# Epoch 26/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1995 - mean_absolute_error: 0.5106 - val_loss: 0.1601 - val_mean_absolute_error: 0.5173
# Epoch 27/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1994 - mean_absolute_error: 0.5106 - val_loss: 0.1601 - val_mean_absolute_error: 0.5173
# Epoch 28/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1994 - mean_absolute_error: 0.5106 - val_loss: 0.1601 - val_mean_absolute_error: 0.5173
# Epoch 29/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1994 - mean_absolute_error: 0.5106 - val_loss: 0.1601 - val_mean_absolute_error: 0.5173
# Epoch 30/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1994 - mean_absolute_error: 0.5105 - val_loss: 0.1601 - val_mean_absolute_error: 0.5173
# Epoch 31/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1993 - mean_absolute_error: 0.5105 - val_loss: 0.1601 - val_mean_absolute_error: 0.5174
# Epoch 32/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1993 - mean_absolute_error: 0.5105 - val_loss: 0.1601 - val_mean_absolute_error: 0.5174
# Epoch 33/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1993 - mean_absolute_error: 0.5104 - val_loss: 0.1601 - val_mean_absolute_error: 0.5174
# Epoch 34/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1992 - mean_absolute_error: 0.5104 - val_loss: 0.1601 - val_mean_absolute_error: 0.5174
# Epoch 35/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1992 - mean_absolute_error: 0.5103 - val_loss: 0.1601 - val_mean_absolute_error: 0.5174
# Epoch 36/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1991 - mean_absolute_error: 0.5103 - val_loss: 0.1601 - val_mean_absolute_error: 0.5175
# Epoch 37/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1990 - mean_absolute_error: 0.5102 - val_loss: 0.1601 - val_mean_absolute_error: 0.5175
# Epoch 38/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1990 - mean_absolute_error: 0.5102 - val_loss: 0.1602 - val_mean_absolute_error: 0.5175
# Epoch 39/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1989 - mean_absolute_error: 0.5101 - val_loss: 0.1602 - val_mean_absolute_error: 0.5176
# Epoch 40/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1988 - mean_absolute_error: 0.5100 - val_loss: 0.1602 - val_mean_absolute_error: 0.5176
# Epoch 41/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1987 - mean_absolute_error: 0.5099 - val_loss: 0.1602 - val_mean_absolute_error: 0.5176
# Epoch 42/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1986 - mean_absolute_error: 0.5098 - val_loss: 0.1602 - val_mean_absolute_error: 0.5177
# Epoch 43/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1985 - mean_absolute_error: 0.5097 - val_loss: 0.1603 - val_mean_absolute_error: 0.5178
# Epoch 44/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1983 - mean_absolute_error: 0.5095 - val_loss: 0.1603 - val_mean_absolute_error: 0.5178
# Epoch 45/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1982 - mean_absolute_error: 0.5094 - val_loss: 0.1603 - val_mean_absolute_error: 0.5179
# Epoch 46/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1980 - mean_absolute_error: 0.5092 - val_loss: 0.1604 - val_mean_absolute_error: 0.5180
# Epoch 47/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1978 - mean_absolute_error: 0.5090 - val_loss: 0.1604 - val_mean_absolute_error: 0.5181
# Epoch 48/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1976 - mean_absolute_error: 0.5088 - val_loss: 0.1605 - val_mean_absolute_error: 0.5182
# Epoch 49/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1973 - mean_absolute_error: 0.5086 - val_loss: 0.1605 - val_mean_absolute_error: 0.5184
# Epoch 50/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1970 - mean_absolute_error: 0.5083 - val_loss: 0.1606 - val_mean_absolute_error: 0.5185
# Epoch 51/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1967 - mean_absolute_error: 0.5080 - val_loss: 0.1606 - val_mean_absolute_error: 0.5186
# Epoch 52/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1964 - mean_absolute_error: 0.5077 - val_loss: 0.1607 - val_mean_absolute_error: 0.5188
# Epoch 53/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1960 - mean_absolute_error: 0.5073 - val_loss: 0.1608 - val_mean_absolute_error: 0.5190
# Epoch 54/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1956 - mean_absolute_error: 0.5069 - val_loss: 0.1609 - val_mean_absolute_error: 0.5192
# Epoch 55/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1951 - mean_absolute_error: 0.5064 - val_loss: 0.1610 - val_mean_absolute_error: 0.5194
# Epoch 56/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1945 - mean_absolute_error: 0.5059 - val_loss: 0.1611 - val_mean_absolute_error: 0.5197
# Epoch 57/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1939 - mean_absolute_error: 0.5053 - val_loss: 0.1612 - val_mean_absolute_error: 0.5200
# Epoch 58/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1932 - mean_absolute_error: 0.5046 - val_loss: 0.1614 - val_mean_absolute_error: 0.5204
# Epoch 59/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1925 - mean_absolute_error: 0.5039 - val_loss: 0.1615 - val_mean_absolute_error: 0.5207
# Epoch 60/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1917 - mean_absolute_error: 0.5031 - val_loss: 0.1617 - val_mean_absolute_error: 0.5212
# Epoch 61/250
# 1822/1822 [==============================] - 5s 2ms/step - loss: 0.1907 - mean_absolute_error: 0.5021 - val_loss: 0.1619 - val_mean_absolute_error: 0.5216
# Epoch 62/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1897 - mean_absolute_error: 0.5011 - val_loss: 0.1621 - val_mean_absolute_error: 0.5221
# Epoch 63/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1885 - mean_absolute_error: 0.5000 - val_loss: 0.1623 - val_mean_absolute_error: 0.5226
# Epoch 64/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1873 - mean_absolute_error: 0.4987 - val_loss: 0.1625 - val_mean_absolute_error: 0.5230
# Epoch 65/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1859 - mean_absolute_error: 0.4974 - val_loss: 0.1627 - val_mean_absolute_error: 0.5236
# Epoch 66/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1843 - mean_absolute_error: 0.4958 - val_loss: 0.1630 - val_mean_absolute_error: 0.5243
# Epoch 67/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1826 - mean_absolute_error: 0.4941 - val_loss: 0.1633 - val_mean_absolute_error: 0.5251
# Epoch 68/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1807 - mean_absolute_error: 0.4922 - val_loss: 0.1637 - val_mean_absolute_error: 0.5260
# Epoch 69/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1786 - mean_absolute_error: 0.4901 - val_loss: 0.1640 - val_mean_absolute_error: 0.5269
# Epoch 70/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1762 - mean_absolute_error: 0.4878 - val_loss: 0.1644 - val_mean_absolute_error: 0.5279
# Epoch 71/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1737 - mean_absolute_error: 0.4851 - val_loss: 0.1648 - val_mean_absolute_error: 0.5289
# Epoch 72/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1709 - mean_absolute_error: 0.4823 - val_loss: 0.1653 - val_mean_absolute_error: 0.5302
# Epoch 73/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1677 - mean_absolute_error: 0.4791 - val_loss: 0.1659 - val_mean_absolute_error: 0.5315
# Epoch 74/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1644 - mean_absolute_error: 0.4756 - val_loss: 0.1664 - val_mean_absolute_error: 0.5329
# Epoch 75/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1607 - mean_absolute_error: 0.4718 - val_loss: 0.1669 - val_mean_absolute_error: 0.5343
# Epoch 76/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1568 - mean_absolute_error: 0.4677 - val_loss: 0.1674 - val_mean_absolute_error: 0.5356
# Epoch 77/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1526 - mean_absolute_error: 0.4632 - val_loss: 0.1676 - val_mean_absolute_error: 0.5366
# Epoch 78/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1483 - mean_absolute_error: 0.4583 - val_loss: 0.1676 - val_mean_absolute_error: 0.5373
# Epoch 79/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1436 - mean_absolute_error: 0.4530 - val_loss: 0.1677 - val_mean_absolute_error: 0.5381
# Epoch 80/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1385 - mean_absolute_error: 0.4470 - val_loss: 0.1675 - val_mean_absolute_error: 0.5386
# Epoch 81/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1330 - mean_absolute_error: 0.4403 - val_loss: 0.1667 - val_mean_absolute_error: 0.5381
# Epoch 82/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1275 - mean_absolute_error: 0.4334 - val_loss: 0.1659 - val_mean_absolute_error: 0.5374
# Epoch 83/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1216 - mean_absolute_error: 0.4256 - val_loss: 0.1643 - val_mean_absolute_error: 0.5357
# Epoch 84/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1153 - mean_absolute_error: 0.4169 - val_loss: 0.1624 - val_mean_absolute_error: 0.5334
# Epoch 85/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1086 - mean_absolute_error: 0.4070 - val_loss: 0.1599 - val_mean_absolute_error: 0.5300
# Epoch 86/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.1017 - mean_absolute_error: 0.3967 - val_loss: 0.1567 - val_mean_absolute_error: 0.5253
# Epoch 87/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0945 - mean_absolute_error: 0.3847 - val_loss: 0.1518 - val_mean_absolute_error: 0.5177
# Epoch 88/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0872 - mean_absolute_error: 0.3715 - val_loss: 0.1456 - val_mean_absolute_error: 0.5072
# Epoch 89/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0796 - mean_absolute_error: 0.3567 - val_loss: 0.1377 - val_mean_absolute_error: 0.4933
# Epoch 90/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0718 - mean_absolute_error: 0.3402 - val_loss: 0.1279 - val_mean_absolute_error: 0.4750
# Epoch 91/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0637 - mean_absolute_error: 0.3217 - val_loss: 0.1165 - val_mean_absolute_error: 0.4527
# Epoch 92/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0554 - mean_absolute_error: 0.3008 - val_loss: 0.1031 - val_mean_absolute_error: 0.4243
# Epoch 93/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0473 - mean_absolute_error: 0.2780 - val_loss: 0.0882 - val_mean_absolute_error: 0.3904
# Epoch 94/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0390 - mean_absolute_error: 0.2523 - val_loss: 0.0726 - val_mean_absolute_error: 0.3512
# Epoch 95/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0311 - mean_absolute_error: 0.2247 - val_loss: 0.0569 - val_mean_absolute_error: 0.3070
# Epoch 96/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0237 - mean_absolute_error: 0.1945 - val_loss: 0.0417 - val_mean_absolute_error: 0.2571
# Epoch 97/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0171 - mean_absolute_error: 0.1629 - val_loss: 0.0284 - val_mean_absolute_error: 0.2044
# Epoch 98/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.1321 - val_loss: 0.0186 - val_mean_absolute_error: 0.1564
# Epoch 99/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.1054 - val_loss: 0.0124 - val_mean_absolute_error: 0.1210
# Epoch 100/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0053 - mean_absolute_error: 0.0844 - val_loss: 0.0093 - val_mean_absolute_error: 0.1042
# Epoch 101/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0040 - mean_absolute_error: 0.0702 - val_loss: 0.0084 - val_mean_absolute_error: 0.1019
# Epoch 102/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0035 - mean_absolute_error: 0.0632 - val_loss: 0.0086 - val_mean_absolute_error: 0.1058
# Epoch 103/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0034 - mean_absolute_error: 0.0603 - val_loss: 0.0090 - val_mean_absolute_error: 0.1088
# Epoch 104/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0034 - mean_absolute_error: 0.0595 - val_loss: 0.0092 - val_mean_absolute_error: 0.1098
# Epoch 105/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0034 - mean_absolute_error: 0.0589 - val_loss: 0.0091 - val_mean_absolute_error: 0.1092
# Epoch 106/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0034 - mean_absolute_error: 0.0589 - val_loss: 0.0089 - val_mean_absolute_error: 0.1081
# Epoch 107/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0034 - mean_absolute_error: 0.0594 - val_loss: 0.0088 - val_mean_absolute_error: 0.1075
# Epoch 108/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0034 - mean_absolute_error: 0.0594 - val_loss: 0.0088 - val_mean_absolute_error: 0.1073
# Epoch 109/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0034 - mean_absolute_error: 0.0592 - val_loss: 0.0088 - val_mean_absolute_error: 0.1073
# Epoch 110/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0034 - mean_absolute_error: 0.0590 - val_loss: 0.0089 - val_mean_absolute_error: 0.1078
# Epoch 111/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0034 - mean_absolute_error: 0.0592 - val_loss: 0.0088 - val_mean_absolute_error: 0.1073
# Epoch 112/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0033 - mean_absolute_error: 0.0594 - val_loss: 0.0088 - val_mean_absolute_error: 0.1068
# Epoch 113/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0033 - mean_absolute_error: 0.0588 - val_loss: 0.0087 - val_mean_absolute_error: 0.1060
# Epoch 114/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0033 - mean_absolute_error: 0.0581 - val_loss: 0.0085 - val_mean_absolute_error: 0.1050
# Epoch 115/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0033 - mean_absolute_error: 0.0590 - val_loss: 0.0087 - val_mean_absolute_error: 0.1067
# Epoch 116/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0033 - mean_absolute_error: 0.0583 - val_loss: 0.0088 - val_mean_absolute_error: 0.1068
# Epoch 117/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0033 - mean_absolute_error: 0.0574 - val_loss: 0.0085 - val_mean_absolute_error: 0.1048
# Epoch 118/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0033 - mean_absolute_error: 0.0581 - val_loss: 0.0084 - val_mean_absolute_error: 0.1042
# Epoch 119/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0032 - mean_absolute_error: 0.0580 - val_loss: 0.0086 - val_mean_absolute_error: 0.1059
# Epoch 120/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0033 - mean_absolute_error: 0.0587 - val_loss: 0.0085 - val_mean_absolute_error: 0.1049
# Epoch 121/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0033 - mean_absolute_error: 0.0564 - val_loss: 0.0082 - val_mean_absolute_error: 0.1025
# Epoch 122/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0032 - mean_absolute_error: 0.0588 - val_loss: 0.0086 - val_mean_absolute_error: 0.1057
# Epoch 123/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0032 - mean_absolute_error: 0.0551 - val_loss: 0.0084 - val_mean_absolute_error: 0.1042
# Epoch 124/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0031 - mean_absolute_error: 0.0559 - val_loss: 0.0082 - val_mean_absolute_error: 0.1021
# Epoch 125/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0031 - mean_absolute_error: 0.0563 - val_loss: 0.0082 - val_mean_absolute_error: 0.1025
# Epoch 126/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0031 - mean_absolute_error: 0.0561 - val_loss: 0.0081 - val_mean_absolute_error: 0.1021
# Epoch 127/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0030 - mean_absolute_error: 0.0547 - val_loss: 0.0080 - val_mean_absolute_error: 0.1010
# Epoch 128/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0030 - mean_absolute_error: 0.0540 - val_loss: 0.0081 - val_mean_absolute_error: 0.1015
# Epoch 129/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0030 - mean_absolute_error: 0.0551 - val_loss: 0.0079 - val_mean_absolute_error: 0.1001
# Epoch 130/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0029 - mean_absolute_error: 0.0554 - val_loss: 0.0079 - val_mean_absolute_error: 0.1004
# Epoch 131/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0029 - mean_absolute_error: 0.0537 - val_loss: 0.0077 - val_mean_absolute_error: 0.0972
# Epoch 132/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0029 - mean_absolute_error: 0.0554 - val_loss: 0.0080 - val_mean_absolute_error: 0.1008
# Epoch 133/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0028 - mean_absolute_error: 0.0518 - val_loss: 0.0075 - val_mean_absolute_error: 0.0962
# Epoch 134/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0027 - mean_absolute_error: 0.0510 - val_loss: 0.0076 - val_mean_absolute_error: 0.0978
# Epoch 135/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0026 - mean_absolute_error: 0.0503 - val_loss: 0.0073 - val_mean_absolute_error: 0.0947
# Epoch 136/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0026 - mean_absolute_error: 0.0501 - val_loss: 0.0073 - val_mean_absolute_error: 0.0951
# Epoch 137/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0025 - mean_absolute_error: 0.0503 - val_loss: 0.0071 - val_mean_absolute_error: 0.0931
# Epoch 138/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0025 - mean_absolute_error: 0.0493 - val_loss: 0.0071 - val_mean_absolute_error: 0.0938
# Epoch 139/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0024 - mean_absolute_error: 0.0489 - val_loss: 0.0069 - val_mean_absolute_error: 0.0920
# Epoch 140/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0023 - mean_absolute_error: 0.0472 - val_loss: 0.0070 - val_mean_absolute_error: 0.0932
# Epoch 141/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0023 - mean_absolute_error: 0.0479 - val_loss: 0.0074 - val_mean_absolute_error: 0.0967
# Epoch 142/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0022 - mean_absolute_error: 0.0466 - val_loss: 0.0065 - val_mean_absolute_error: 0.0876
# Epoch 143/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0023 - mean_absolute_error: 0.0512 - val_loss: 0.0062 - val_mean_absolute_error: 0.0873
# Epoch 144/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0023 - mean_absolute_error: 0.0526 - val_loss: 0.0076 - val_mean_absolute_error: 0.0984
# Epoch 145/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0021 - mean_absolute_error: 0.0463 - val_loss: 0.0060 - val_mean_absolute_error: 0.0850
# Epoch 146/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0024 - mean_absolute_error: 0.0568 - val_loss: 0.0059 - val_mean_absolute_error: 0.0843
# Epoch 147/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0039 - mean_absolute_error: 0.0731 - val_loss: 0.0060 - val_mean_absolute_error: 0.0863
# Epoch 148/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0797 - val_loss: 0.0068 - val_mean_absolute_error: 0.0898
# Epoch 149/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0040 - mean_absolute_error: 0.0738 - val_loss: 0.0059 - val_mean_absolute_error: 0.0856
# Epoch 150/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0025 - mean_absolute_error: 0.0568 - val_loss: 0.0057 - val_mean_absolute_error: 0.0833
# Epoch 151/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0025 - mean_absolute_error: 0.0577 - val_loss: 0.0055 - val_mean_absolute_error: 0.0815
# Epoch 152/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0421 - val_loss: 0.0053 - val_mean_absolute_error: 0.0803
# Epoch 153/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0033 - mean_absolute_error: 0.0661 - val_loss: 0.0054 - val_mean_absolute_error: 0.0814
# Epoch 154/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0099 - mean_absolute_error: 0.1127 - val_loss: 0.0072 - val_mean_absolute_error: 0.0954
# Epoch 155/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0428 - mean_absolute_error: 0.2044 - val_loss: 4.4730 - val_mean_absolute_error: 4.9722
# Epoch 156/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 9.1944 - mean_absolute_error: 9.6872 - val_loss: 46.4904 - val_mean_absolute_error: 46.9904
# Epoch 157/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 47.7510 - mean_absolute_error: 48.2510 - val_loss: 124.3209 - val_mean_absolute_error: 124.8209
# Epoch 158/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 65.9032 - mean_absolute_error: 66.3806 - val_loss: 103.6856 - val_mean_absolute_error: 104.1856
# Epoch 159/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 45.9859 - mean_absolute_error: 46.4620 - val_loss: 3.9007 - val_mean_absolute_error: 4.4007
# Epoch 160/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 24.9604 - mean_absolute_error: 25.4604 - val_loss: 31.4586 - val_mean_absolute_error: 31.9586
# Epoch 161/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 30.0800 - mean_absolute_error: 30.5755 - val_loss: 70.3954 - val_mean_absolute_error: 70.8954
# Epoch 162/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 95.9627 - mean_absolute_error: 96.4627 - val_loss: 209.9280 - val_mean_absolute_error: 210.4280
# Epoch 163/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 87.2287 - mean_absolute_error: 87.7287 - val_loss: 0.1932 - val_mean_absolute_error: 0.5761
# Epoch 164/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 66.8455 - mean_absolute_error: 67.3409 - val_loss: 128.0792 - val_mean_absolute_error: 128.5792
# Epoch 165/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 70.1189 - mean_absolute_error: 70.6189 - val_loss: 130.8806 - val_mean_absolute_error: 131.3806
# Epoch 166/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 113.5056 - mean_absolute_error: 114.0056 - val_loss: 116.2726 - val_mean_absolute_error: 116.7725
# Epoch 167/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 129.3225 - mean_absolute_error: 129.8225 - val_loss: 89.0385 - val_mean_absolute_error: 89.5385
# Epoch 168/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 46.9119 - mean_absolute_error: 47.4119 - val_loss: 209.7604 - val_mean_absolute_error: 210.2603
# Epoch 169/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 154.6837 - mean_absolute_error: 155.1837 - val_loss: 16.4073 - val_mean_absolute_error: 16.9073
# Epoch 170/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 134.4909 - mean_absolute_error: 134.9910 - val_loss: 264.5087 - val_mean_absolute_error: 265.0087
# Epoch 171/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 137.3870 - mean_absolute_error: 137.8870 - val_loss: 280.5230 - val_mean_absolute_error: 281.0230
# Epoch 172/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 229.8495 - mean_absolute_error: 230.3495 - val_loss: 255.8636 - val_mean_absolute_error: 256.3637
# Epoch 173/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 261.7903 - mean_absolute_error: 262.2903 - val_loss: 152.8489 - val_mean_absolute_error: 153.3490
# Epoch 174/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 176.5436 - mean_absolute_error: 177.0436 - val_loss: 286.0975 - val_mean_absolute_error: 286.5976
# Epoch 175/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 312.5635 - mean_absolute_error: 313.0635 - val_loss: 153.1687 - val_mean_absolute_error: 153.6687
# Epoch 176/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 337.9438 - mean_absolute_error: 338.4438 - val_loss: 466.7933 - val_mean_absolute_error: 467.2934
# Epoch 177/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 391.7245 - mean_absolute_error: 392.2246 - val_loss: 571.3815 - val_mean_absolute_error: 571.8814
# Epoch 178/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 480.9158 - mean_absolute_error: 481.4158 - val_loss: 127.5238 - val_mean_absolute_error: 128.0238
# Epoch 179/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 450.2605 - mean_absolute_error: 450.7605 - val_loss: 858.8471 - val_mean_absolute_error: 859.3470
# Epoch 180/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 587.4805 - mean_absolute_error: 587.9805 - val_loss: 560.5716 - val_mean_absolute_error: 561.0716
# Epoch 181/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 641.8595 - mean_absolute_error: 642.3594 - val_loss: 85.8215 - val_mean_absolute_error: 86.3215
# Epoch 182/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 193.0972 - mean_absolute_error: 193.5972 - val_loss: 1021.7237 - val_mean_absolute_error: 1022.2236
# Epoch 183/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 887.1129 - mean_absolute_error: 887.6128 - val_loss: 373.0307 - val_mean_absolute_error: 373.5307
# Epoch 184/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 861.0015 - mean_absolute_error: 861.5016 - val_loss: 408.7814 - val_mean_absolute_error: 409.2815
# Epoch 185/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 609.4939 - mean_absolute_error: 609.9939 - val_loss: 2203.1578 - val_mean_absolute_error: 2203.6580
# Epoch 186/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 899.8059 - mean_absolute_error: 900.3058 - val_loss: 613.7899 - val_mean_absolute_error: 614.2898
# Epoch 187/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 1022.4519 - mean_absolute_error: 1022.9519 - val_loss: 431.5859 - val_mean_absolute_error: 432.0858
# Epoch 188/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 630.5461 - mean_absolute_error: 631.0461 - val_loss: 1440.0809 - val_mean_absolute_error: 1440.5809
# Epoch 189/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 1508.0040 - mean_absolute_error: 1508.5038 - val_loss: 1989.4593 - val_mean_absolute_error: 1989.9598
# Epoch 190/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 1752.0301 - mean_absolute_error: 1752.5299 - val_loss: 2368.6236 - val_mean_absolute_error: 2369.1237
# Epoch 191/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 2127.3062 - mean_absolute_error: 2127.8064 - val_loss: 264.2535 - val_mean_absolute_error: 264.7536
# Epoch 192/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 1967.4933 - mean_absolute_error: 1967.9932 - val_loss: 4197.5061 - val_mean_absolute_error: 4198.0070
# Epoch 193/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 2683.1419 - mean_absolute_error: 2683.6417 - val_loss: 2123.7430 - val_mean_absolute_error: 2124.2429
# Epoch 194/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 2809.6893 - mean_absolute_error: 2810.1888 - val_loss: 776.7541 - val_mean_absolute_error: 777.2540
# Epoch 195/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 1393.6638 - mean_absolute_error: 1394.1638 - val_loss: 2931.8270 - val_mean_absolute_error: 2932.3267
# Epoch 196/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 3309.6979 - mean_absolute_error: 3310.1982 - val_loss: 4955.0256 - val_mean_absolute_error: 4955.5260
# Epoch 197/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 4006.5060 - mean_absolute_error: 4007.0059 - val_loss: 4713.2974 - val_mean_absolute_error: 4713.7967
# Epoch 198/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 4672.5131 - mean_absolute_error: 4673.0133 - val_loss: 35.2632 - val_mean_absolute_error: 35.7632
# Epoch 199/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 1295.3752 - mean_absolute_error: 1295.8752 - val_loss: 2585.2478 - val_mean_absolute_error: 2585.7479
# Epoch 200/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 1631.8536 - mean_absolute_error: 1632.3533 - val_loss: 1983.3451 - val_mean_absolute_error: 1983.8448
# Epoch 201/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 1658.0789 - mean_absolute_error: 1658.5789 - val_loss: 181.7261 - val_mean_absolute_error: 182.2260
# Epoch 202/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 7125.9059 - mean_absolute_error: 7126.4063 - val_loss: 7279.3355 - val_mean_absolute_error: 7279.8359
# Epoch 203/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 7456.1543 - mean_absolute_error: 7456.6541 - val_loss: 789.8776 - val_mean_absolute_error: 790.3777
# Epoch 204/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 6822.8145 - mean_absolute_error: 6823.3144 - val_loss: 11960.4033 - val_mean_absolute_error: 11960.9041
# Epoch 205/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 4834.0409 - mean_absolute_error: 4834.5410 - val_loss: 11955.9782 - val_mean_absolute_error: 11956.4802
# Epoch 206/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 15140.7101 - mean_absolute_error: 15141.2078 - val_loss: 34560.8059 - val_mean_absolute_error: 34561.3103
# Epoch 207/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 14044.1909 - mean_absolute_error: 14044.6904 - val_loss: 1512.6266 - val_mean_absolute_error: 1513.1262
# Epoch 208/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 10351.1202 - mean_absolute_error: 10351.6219 - val_loss: 28494.5492 - val_mean_absolute_error: 28495.0491
# Epoch 209/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 26643.1011 - mean_absolute_error: 26643.5969 - val_loss: 14009.1815 - val_mean_absolute_error: 14009.6815
# Epoch 210/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 11372.9841 - mean_absolute_error: 11373.4838 - val_loss: 31357.6614 - val_mean_absolute_error: 31358.1626
# Epoch 211/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 17030.3545 - mean_absolute_error: 17030.8559 - val_loss: 2714.6757 - val_mean_absolute_error: 2715.1760
# Epoch 212/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 24131.9801 - mean_absolute_error: 24132.4843 - val_loss: 11885.0475 - val_mean_absolute_error: 11885.5494
# Epoch 213/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 14522.7030 - mean_absolute_error: 14523.2033 - val_loss: 36757.8799 - val_mean_absolute_error: 36758.3694
# Epoch 214/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 29465.9307 - mean_absolute_error: 29466.4316 - val_loss: 28971.4279 - val_mean_absolute_error: 28971.9319
# Epoch 215/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 32326.4365 - mean_absolute_error: 32326.9393 - val_loss: 24622.8090 - val_mean_absolute_error: 24623.3112
# Epoch 216/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 11541.1824 - mean_absolute_error: 11541.6824 - val_loss: 55709.6448 - val_mean_absolute_error: 55710.1558
# Epoch 217/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 39321.2626 - mean_absolute_error: 39321.7630 - val_loss: 7470.0066 - val_mean_absolute_error: 7470.5053
# Epoch 218/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 34290.3369 - mean_absolute_error: 34290.8316 - val_loss: 63201.6956 - val_mean_absolute_error: 63202.2075
# Epoch 219/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 35140.8226 - mean_absolute_error: 35141.3244 - val_loss: 67163.4084 - val_mean_absolute_error: 67163.9163
# Epoch 220/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 57352.5421 - mean_absolute_error: 57353.0495 - val_loss: 60943.0723 - val_mean_absolute_error: 60943.5859
# Epoch 221/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 65482.8677 - mean_absolute_error: 65483.3832 - val_loss: 41982.4297 - val_mean_absolute_error: 41982.9258
# Epoch 222/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 44981.1614 - mean_absolute_error: 44981.6746 - val_loss: 68521.2644 - val_mean_absolute_error: 68521.7600
# Epoch 223/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 78119.3971 - mean_absolute_error: 78119.9075 - val_loss: 35128.8816 - val_mean_absolute_error: 35129.3772
# Epoch 224/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 84609.3759 - mean_absolute_error: 84609.8698 - val_loss: 120849.6175 - val_mean_absolute_error: 120850.1218
# Epoch 225/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 99029.5477 - mean_absolute_error: 99030.0423 - val_loss: 140177.8747 - val_mean_absolute_error: 140178.3660
# Epoch 226/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 120406.1937 - mean_absolute_error: 120406.6895 - val_loss: 28685.5710 - val_mean_absolute_error: 28686.0666
# Epoch 227/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 112819.8482 - mean_absolute_error: 112820.3392 - val_loss: 219329.9367 - val_mean_absolute_error: 219330.4397
# Epoch 228/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 148204.7997 - mean_absolute_error: 148205.3107 - val_loss: 137462.1560 - val_mean_absolute_error: 137462.6785
# Epoch 229/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 160834.0211 - mean_absolute_error: 160834.4871 - val_loss: 25154.6801 - val_mean_absolute_error: 25155.1805
# Epoch 230/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 49143.7145 - mean_absolute_error: 49144.2155 - val_loss: 253298.2829 - val_mean_absolute_error: 253298.7547
# Epoch 231/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 222441.1096 - mean_absolute_error: 222441.5821 - val_loss: 97298.2800 - val_mean_absolute_error: 97298.7712
# Epoch 232/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 216917.4063 - mean_absolute_error: 216917.9254 - val_loss: 99333.8825 - val_mean_absolute_error: 99334.3694
# Epoch 233/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 151897.9082 - mean_absolute_error: 151898.4265 - val_loss: 557006.0274 - val_mean_absolute_error: 557006.5822
# Epoch 234/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 596333.6090 - mean_absolute_error: 596334.0870 - val_loss: 698955.5395 - val_mean_absolute_error: 698955.9024
# Epoch 235/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 817796.5401 - mean_absolute_error: 817797.0291 - val_loss: 928453.0537 - val_mean_absolute_error: 928453.6129
# Epoch 236/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 665220.8196 - mean_absolute_error: 665221.2388 - val_loss: 1428956.1250 - val_mean_absolute_error: 1428956.4298
# Epoch 237/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 1106019.1378 - mean_absolute_error: 1106019.5125 - val_loss: 354812.8284 - val_mean_absolute_error: 354813.2484
# Epoch 238/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 685227.8798 - mean_absolute_error: 685228.2717 - val_loss: 421243.1541 - val_mean_absolute_error: 421243.7730
# Epoch 239/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 283213.1793 - mean_absolute_error: 283213.6787 - val_loss: 75053.3518 - val_mean_absolute_error: 75053.8372
# Epoch 240/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 301184.6725 - mean_absolute_error: 301185.1680 - val_loss: 1237750.1404 - val_mean_absolute_error: 1237750.6645
# Epoch 241/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 437188.2788 - mean_absolute_error: 437188.6973 - val_loss: 725907.8904 - val_mean_absolute_error: 725908.2226
# Epoch 242/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 908992.4498 - mean_absolute_error: 908992.8500 - val_loss: 1982446.6535 - val_mean_absolute_error: 1982447.1404
# Epoch 243/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 1231460.0176 - mean_absolute_error: 1231460.6979 - val_loss: 2126996.2500 - val_mean_absolute_error: 2126997.3904
# Epoch 244/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 1547226.0349 - mean_absolute_error: 1547226.3779 - val_loss: 1744512.1250 - val_mean_absolute_error: 1744512.6404
# Epoch 245/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 1881698.6371 - mean_absolute_error: 1881698.9650 - val_loss: 1080893.8750 - val_mean_absolute_error: 1080894.0548
# Epoch 246/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 1198478.0398 - mean_absolute_error: 1198478.4715 - val_loss: 410117.5230 - val_mean_absolute_error: 410117.9315
# Epoch 247/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 2018432.3377 - mean_absolute_error: 2018432.5941 - val_loss: 119575.8562 - val_mean_absolute_error: 119576.3494
# Epoch 248/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 671997.8293 - mean_absolute_error: 671998.4446 - val_loss: 469743.9512 - val_mean_absolute_error: 469744.2758
# Epoch 249/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 1636964.9064 - mean_absolute_error: 1636965.7448 - val_loss: 1425182.4605 - val_mean_absolute_error: 1425182.8596
# Epoch 250/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 2753122.1339 - mean_absolute_error: 2753122.5637 - val_loss: 1496120.0000 - val_mean_absolute_error: 1496120.2895

# %% [markdown]
# Let's plot the loss for the testing data versus the learning rate.  We can see that it explodes past a learning rate of 1, so let's focus our window to before this point.

# %%
plt.semilogx(history.history['lr'], history.history['val_loss'])
plt.legend(['Learning Rate', 'Validation Loss'])

# %%
plt.semilogx(history.history['lr'][:140], history.history['loss'][:140])

# %% [markdown]
# It looks like the learning rate of 0.1 seems to work the best.  Let's use that learning rate and train the network this time for real.  Once we train the network, let's predict the prices for the training and test data.

# %%
# Observing the above graph, 0.1 seems to be the best learning rate
keras_model = Sequential([
  Conv1D(filters=128, kernel_size=5, input_shape=(window_size, 1), strides=1, padding="causal", activation="tanh"),
  Conv1D(filters=128, kernel_size=5, strides=1, padding="causal", activation="tanh"),
  LSTM(128, return_sequences=True),
  LSTM(128),
  Dense(64, activation="tanh"),
  Dense(64, activation="tanh"),
  Dense(1)
])


optimizer = SGD(lr=0.1, momentum=0.9)
keras_model.compile(loss=Huber(),
                    optimizer=optimizer,
                    metrics=["mae"])
history = keras_model.fit(X_train_reshape, y_train_reshape, batch_size=256, epochs=250, validation_data=(X_test_reshape, y_test_reshape))
# Out:
# Train on 1822 samples, validate on 456 samples
# Epoch 1/250
# 1822/1822 [==============================] - 7s 4ms/step - loss: 0.0691 - mean_absolute_error: 0.3068 - val_loss: 0.0504 - val_mean_absolute_error: 0.2896
# Epoch 2/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0256 - mean_absolute_error: 0.1922 - val_loss: 0.0090 - val_mean_absolute_error: 0.1082
# Epoch 3/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0117 - mean_absolute_error: 0.1155 - val_loss: 0.0219 - val_mean_absolute_error: 0.1782
# Epoch 4/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0072 - mean_absolute_error: 0.0932 - val_loss: 0.0091 - val_mean_absolute_error: 0.1060
# Epoch 5/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0050 - mean_absolute_error: 0.0767 - val_loss: 0.0082 - val_mean_absolute_error: 0.1005
# Epoch 6/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0036 - mean_absolute_error: 0.0619 - val_loss: 0.0096 - val_mean_absolute_error: 0.1130
# Epoch 7/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0031 - mean_absolute_error: 0.0565 - val_loss: 0.0073 - val_mean_absolute_error: 0.0954
# Epoch 8/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0026 - mean_absolute_error: 0.0505 - val_loss: 0.0074 - val_mean_absolute_error: 0.0939
# Epoch 9/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0024 - mean_absolute_error: 0.0490 - val_loss: 0.0075 - val_mean_absolute_error: 0.0972
# Epoch 10/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0023 - mean_absolute_error: 0.0481 - val_loss: 0.0075 - val_mean_absolute_error: 0.0961
# Epoch 11/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0022 - mean_absolute_error: 0.0488 - val_loss: 0.0073 - val_mean_absolute_error: 0.0944
# Epoch 12/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0021 - mean_absolute_error: 0.0458 - val_loss: 0.0070 - val_mean_absolute_error: 0.0909
# Epoch 13/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0020 - mean_absolute_error: 0.0462 - val_loss: 0.0071 - val_mean_absolute_error: 0.0912
# Epoch 14/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0019 - mean_absolute_error: 0.0426 - val_loss: 0.0073 - val_mean_absolute_error: 0.0933
# Epoch 15/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0019 - mean_absolute_error: 0.0425 - val_loss: 0.0071 - val_mean_absolute_error: 0.0921
# Epoch 16/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0019 - mean_absolute_error: 0.0423 - val_loss: 0.0071 - val_mean_absolute_error: 0.0921
# Epoch 17/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0019 - mean_absolute_error: 0.0439 - val_loss: 0.0069 - val_mean_absolute_error: 0.0900
# Epoch 18/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0019 - mean_absolute_error: 0.0436 - val_loss: 0.0071 - val_mean_absolute_error: 0.0922
# Epoch 19/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0434 - val_loss: 0.0068 - val_mean_absolute_error: 0.0902
# Epoch 20/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0019 - mean_absolute_error: 0.0452 - val_loss: 0.0067 - val_mean_absolute_error: 0.0892
# Epoch 21/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0019 - mean_absolute_error: 0.0455 - val_loss: 0.0066 - val_mean_absolute_error: 0.0885
# Epoch 22/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0438 - val_loss: 0.0076 - val_mean_absolute_error: 0.0972
# Epoch 23/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0019 - mean_absolute_error: 0.0437 - val_loss: 0.0072 - val_mean_absolute_error: 0.0939
# Epoch 24/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0019 - mean_absolute_error: 0.0437 - val_loss: 0.0066 - val_mean_absolute_error: 0.0882
# Epoch 25/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0413 - val_loss: 0.0066 - val_mean_absolute_error: 0.0887
# Epoch 26/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0409 - val_loss: 0.0065 - val_mean_absolute_error: 0.0875
# Epoch 27/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0421 - val_loss: 0.0065 - val_mean_absolute_error: 0.0884
# Epoch 28/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0412 - val_loss: 0.0064 - val_mean_absolute_error: 0.0878
# Epoch 29/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0409 - val_loss: 0.0069 - val_mean_absolute_error: 0.0917
# Epoch 30/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0405 - val_loss: 0.0063 - val_mean_absolute_error: 0.0865
# Epoch 31/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0403 - val_loss: 0.0063 - val_mean_absolute_error: 0.0863
# Epoch 32/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0405 - val_loss: 0.0063 - val_mean_absolute_error: 0.0868
# Epoch 33/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0419 - val_loss: 0.0069 - val_mean_absolute_error: 0.0922
# Epoch 34/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0411 - val_loss: 0.0064 - val_mean_absolute_error: 0.0881
# Epoch 35/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0399 - val_loss: 0.0066 - val_mean_absolute_error: 0.0874
# Epoch 36/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0415 - val_loss: 0.0061 - val_mean_absolute_error: 0.0852
# Epoch 37/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0016 - mean_absolute_error: 0.0407 - val_loss: 0.0060 - val_mean_absolute_error: 0.0852
# Epoch 38/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0016 - mean_absolute_error: 0.0399 - val_loss: 0.0061 - val_mean_absolute_error: 0.0862
# Epoch 39/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0016 - mean_absolute_error: 0.0403 - val_loss: 0.0059 - val_mean_absolute_error: 0.0842
# Epoch 40/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0016 - mean_absolute_error: 0.0396 - val_loss: 0.0059 - val_mean_absolute_error: 0.0841
# Epoch 41/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0016 - mean_absolute_error: 0.0401 - val_loss: 0.0061 - val_mean_absolute_error: 0.0862
# Epoch 42/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0016 - mean_absolute_error: 0.0394 - val_loss: 0.0062 - val_mean_absolute_error: 0.0870
# Epoch 43/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0016 - mean_absolute_error: 0.0396 - val_loss: 0.0058 - val_mean_absolute_error: 0.0835
# Epoch 44/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0016 - mean_absolute_error: 0.0383 - val_loss: 0.0062 - val_mean_absolute_error: 0.0851
# Epoch 45/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0411 - val_loss: 0.0057 - val_mean_absolute_error: 0.0826
# Epoch 46/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0384 - val_loss: 0.0056 - val_mean_absolute_error: 0.0825
# Epoch 47/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0379 - val_loss: 0.0057 - val_mean_absolute_error: 0.0833
# Epoch 48/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0377 - val_loss: 0.0057 - val_mean_absolute_error: 0.0828
# Epoch 49/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0381 - val_loss: 0.0055 - val_mean_absolute_error: 0.0816
# Epoch 50/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0016 - mean_absolute_error: 0.0391 - val_loss: 0.0056 - val_mean_absolute_error: 0.0820
# Epoch 51/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0016 - mean_absolute_error: 0.0419 - val_loss: 0.0060 - val_mean_absolute_error: 0.0831
# Epoch 52/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0016 - mean_absolute_error: 0.0397 - val_loss: 0.0055 - val_mean_absolute_error: 0.0809
# Epoch 53/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0383 - val_loss: 0.0054 - val_mean_absolute_error: 0.0805
# Epoch 54/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0385 - val_loss: 0.0058 - val_mean_absolute_error: 0.0840
# Epoch 55/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0386 - val_loss: 0.0054 - val_mean_absolute_error: 0.0805
# Epoch 56/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0380 - val_loss: 0.0053 - val_mean_absolute_error: 0.0804
# Epoch 57/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0371 - val_loss: 0.0054 - val_mean_absolute_error: 0.0806
# Epoch 58/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0385 - val_loss: 0.0053 - val_mean_absolute_error: 0.0793
# Epoch 59/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0392 - val_loss: 0.0052 - val_mean_absolute_error: 0.0788
# Epoch 60/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0392 - val_loss: 0.0052 - val_mean_absolute_error: 0.0791
# Epoch 61/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0368 - val_loss: 0.0051 - val_mean_absolute_error: 0.0783
# Epoch 62/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0370 - val_loss: 0.0055 - val_mean_absolute_error: 0.0817
# Epoch 63/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0358 - val_loss: 0.0051 - val_mean_absolute_error: 0.0783
# Epoch 64/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0359 - val_loss: 0.0061 - val_mean_absolute_error: 0.0860
# Epoch 65/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0387 - val_loss: 0.0051 - val_mean_absolute_error: 0.0781
# Epoch 66/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0365 - val_loss: 0.0052 - val_mean_absolute_error: 0.0778
# Epoch 67/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0371 - val_loss: 0.0050 - val_mean_absolute_error: 0.0774
# Epoch 68/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0367 - val_loss: 0.0049 - val_mean_absolute_error: 0.0766
# Epoch 69/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0354 - val_loss: 0.0049 - val_mean_absolute_error: 0.0771
# Epoch 70/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0354 - val_loss: 0.0048 - val_mean_absolute_error: 0.0761
# Epoch 71/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0342 - val_loss: 0.0048 - val_mean_absolute_error: 0.0758
# Epoch 72/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0351 - val_loss: 0.0048 - val_mean_absolute_error: 0.0760
# Epoch 73/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0348 - val_loss: 0.0051 - val_mean_absolute_error: 0.0784
# Epoch 74/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0347 - val_loss: 0.0048 - val_mean_absolute_error: 0.0761
# Epoch 75/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0348 - val_loss: 0.0051 - val_mean_absolute_error: 0.0783
# Epoch 76/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0363 - val_loss: 0.0048 - val_mean_absolute_error: 0.0760
# Epoch 77/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0363 - val_loss: 0.0047 - val_mean_absolute_error: 0.0752
# Epoch 78/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0355 - val_loss: 0.0047 - val_mean_absolute_error: 0.0746
# Epoch 79/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0350 - val_loss: 0.0049 - val_mean_absolute_error: 0.0764
# Epoch 80/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0382 - val_loss: 0.0046 - val_mean_absolute_error: 0.0739
# Epoch 81/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0359 - val_loss: 0.0046 - val_mean_absolute_error: 0.0742
# Epoch 82/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0347 - val_loss: 0.0050 - val_mean_absolute_error: 0.0761
# Epoch 83/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0346 - val_loss: 0.0047 - val_mean_absolute_error: 0.0741
# Epoch 84/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0344 - val_loss: 0.0044 - val_mean_absolute_error: 0.0724
# Epoch 85/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0336 - val_loss: 0.0045 - val_mean_absolute_error: 0.0727
# Epoch 86/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0327 - val_loss: 0.0045 - val_mean_absolute_error: 0.0729
# Epoch 87/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0329 - val_loss: 0.0044 - val_mean_absolute_error: 0.0716
# Epoch 88/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0327 - val_loss: 0.0047 - val_mean_absolute_error: 0.0748
# Epoch 89/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0339 - val_loss: 0.0043 - val_mean_absolute_error: 0.0715
# Epoch 90/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0347 - val_loss: 0.0047 - val_mean_absolute_error: 0.0736
# Epoch 91/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0360 - val_loss: 0.0045 - val_mean_absolute_error: 0.0729
# Epoch 92/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0343 - val_loss: 0.0045 - val_mean_absolute_error: 0.0727
# Epoch 93/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0350 - val_loss: 0.0042 - val_mean_absolute_error: 0.0702
# Epoch 94/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0346 - val_loss: 0.0042 - val_mean_absolute_error: 0.0706
# Epoch 95/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0322 - val_loss: 0.0042 - val_mean_absolute_error: 0.0703
# Epoch 96/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0320 - val_loss: 0.0042 - val_mean_absolute_error: 0.0698
# Epoch 97/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0318 - val_loss: 0.0045 - val_mean_absolute_error: 0.0726
# Epoch 98/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0326 - val_loss: 0.0042 - val_mean_absolute_error: 0.0702
# Epoch 99/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0318 - val_loss: 0.0041 - val_mean_absolute_error: 0.0689
# Epoch 100/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0317 - val_loss: 0.0042 - val_mean_absolute_error: 0.0701
# Epoch 101/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0330 - val_loss: 0.0040 - val_mean_absolute_error: 0.0683
# Epoch 102/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0334 - val_loss: 0.0041 - val_mean_absolute_error: 0.0686
# Epoch 103/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0335 - val_loss: 0.0044 - val_mean_absolute_error: 0.0721
# Epoch 104/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0324 - val_loss: 0.0043 - val_mean_absolute_error: 0.0713
# Epoch 105/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0335 - val_loss: 0.0042 - val_mean_absolute_error: 0.0698
# Epoch 106/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0311 - val_loss: 0.0042 - val_mean_absolute_error: 0.0701
# Epoch 107/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0313 - val_loss: 0.0041 - val_mean_absolute_error: 0.0689
# Epoch 108/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0321 - val_loss: 0.0039 - val_mean_absolute_error: 0.0671
# Epoch 109/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0309 - val_loss: 0.0039 - val_mean_absolute_error: 0.0669
# Epoch 110/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0306 - val_loss: 0.0039 - val_mean_absolute_error: 0.0673
# Epoch 111/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0308 - val_loss: 0.0039 - val_mean_absolute_error: 0.0679
# Epoch 112/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0323 - val_loss: 0.0038 - val_mean_absolute_error: 0.0661
# Epoch 113/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0314 - val_loss: 0.0038 - val_mean_absolute_error: 0.0660
# Epoch 114/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0314 - val_loss: 0.0038 - val_mean_absolute_error: 0.0662
# Epoch 115/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0316 - val_loss: 0.0038 - val_mean_absolute_error: 0.0664
# Epoch 116/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0304 - val_loss: 0.0037 - val_mean_absolute_error: 0.0655
# Epoch 117/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0298 - val_loss: 0.0037 - val_mean_absolute_error: 0.0657
# Epoch 118/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0322 - val_loss: 0.0037 - val_mean_absolute_error: 0.0654
# Epoch 119/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0308 - val_loss: 0.0038 - val_mean_absolute_error: 0.0663
# Epoch 120/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0330 - val_loss: 0.0037 - val_mean_absolute_error: 0.0653
# Epoch 121/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0297 - val_loss: 0.0036 - val_mean_absolute_error: 0.0646
# Epoch 122/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0305 - val_loss: 0.0036 - val_mean_absolute_error: 0.0646
# Epoch 123/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0317 - val_loss: 0.0041 - val_mean_absolute_error: 0.0686
# Epoch 124/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0324 - val_loss: 0.0037 - val_mean_absolute_error: 0.0646
# Epoch 125/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0321 - val_loss: 0.0036 - val_mean_absolute_error: 0.0642
# Epoch 126/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0308 - val_loss: 0.0043 - val_mean_absolute_error: 0.0699
# Epoch 127/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0310 - val_loss: 0.0035 - val_mean_absolute_error: 0.0638
# Epoch 128/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0312 - val_loss: 0.0035 - val_mean_absolute_error: 0.0634
# Epoch 129/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0307 - val_loss: 0.0035 - val_mean_absolute_error: 0.0632
# Epoch 130/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0316 - val_loss: 0.0037 - val_mean_absolute_error: 0.0661
# Epoch 131/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0315 - val_loss: 0.0038 - val_mean_absolute_error: 0.0669
# Epoch 132/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0308 - val_loss: 0.0034 - val_mean_absolute_error: 0.0629
# Epoch 133/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.6910e-04 - mean_absolute_error: 0.0298 - val_loss: 0.0035 - val_mean_absolute_error: 0.0633
# Epoch 134/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.7633e-04 - mean_absolute_error: 0.0302 - val_loss: 0.0034 - val_mean_absolute_error: 0.0627
# Epoch 135/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.9001e-04 - mean_absolute_error: 0.0294 - val_loss: 0.0034 - val_mean_absolute_error: 0.0630
# Epoch 136/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.8972e-04 - mean_absolute_error: 0.0302 - val_loss: 0.0034 - val_mean_absolute_error: 0.0623
# Epoch 137/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0305 - val_loss: 0.0035 - val_mean_absolute_error: 0.0641
# Epoch 138/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0308 - val_loss: 0.0034 - val_mean_absolute_error: 0.0625
# Epoch 139/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.8353e-04 - mean_absolute_error: 0.0297 - val_loss: 0.0033 - val_mean_absolute_error: 0.0620
# Epoch 140/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0303 - val_loss: 0.0033 - val_mean_absolute_error: 0.0617
# Epoch 141/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.5193e-04 - mean_absolute_error: 0.0298 - val_loss: 0.0034 - val_mean_absolute_error: 0.0619
# Epoch 142/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.4871e-04 - mean_absolute_error: 0.0297 - val_loss: 0.0033 - val_mean_absolute_error: 0.0616
# Epoch 143/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.2291e-04 - mean_absolute_error: 0.0285 - val_loss: 0.0038 - val_mean_absolute_error: 0.0660
# Epoch 144/250
# 1822/1822 [==============================] - 5s 2ms/step - loss: 9.8753e-04 - mean_absolute_error: 0.0297 - val_loss: 0.0037 - val_mean_absolute_error: 0.0649
# Epoch 145/250
# 1822/1822 [==============================] - 5s 2ms/step - loss: 9.6290e-04 - mean_absolute_error: 0.0286 - val_loss: 0.0033 - val_mean_absolute_error: 0.0614
# Epoch 146/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.1888e-04 - mean_absolute_error: 0.0293 - val_loss: 0.0034 - val_mean_absolute_error: 0.0632
# Epoch 147/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.5944e-04 - mean_absolute_error: 0.0299 - val_loss: 0.0034 - val_mean_absolute_error: 0.0634
# Epoch 148/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0304 - val_loss: 0.0034 - val_mean_absolute_error: 0.0629
# Epoch 149/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.6021e-04 - mean_absolute_error: 0.0292 - val_loss: 0.0034 - val_mean_absolute_error: 0.0632
# Epoch 150/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.8342e-04 - mean_absolute_error: 0.0297 - val_loss: 0.0033 - val_mean_absolute_error: 0.0619
# Epoch 151/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.1279e-04 - mean_absolute_error: 0.0283 - val_loss: 0.0032 - val_mean_absolute_error: 0.0606
# Epoch 152/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.1458e-04 - mean_absolute_error: 0.0287 - val_loss: 0.0033 - val_mean_absolute_error: 0.0608
# Epoch 153/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.9626e-04 - mean_absolute_error: 0.0277 - val_loss: 0.0032 - val_mean_absolute_error: 0.0614
# Epoch 154/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.4279e-04 - mean_absolute_error: 0.0285 - val_loss: 0.0032 - val_mean_absolute_error: 0.0604
# Epoch 155/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.0949e-04 - mean_absolute_error: 0.0288 - val_loss: 0.0031 - val_mean_absolute_error: 0.0601
# Epoch 156/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.2176e-04 - mean_absolute_error: 0.0297 - val_loss: 0.0031 - val_mean_absolute_error: 0.0603
# Epoch 157/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.9210e-04 - mean_absolute_error: 0.0282 - val_loss: 0.0032 - val_mean_absolute_error: 0.0602
# Epoch 158/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.1149e-04 - mean_absolute_error: 0.0285 - val_loss: 0.0033 - val_mean_absolute_error: 0.0610
# Epoch 159/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.2367e-04 - mean_absolute_error: 0.0283 - val_loss: 0.0039 - val_mean_absolute_error: 0.0670
# Epoch 160/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0309 - val_loss: 0.0037 - val_mean_absolute_error: 0.0643
# Epoch 161/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.4225e-04 - mean_absolute_error: 0.0289 - val_loss: 0.0038 - val_mean_absolute_error: 0.0657
# Epoch 162/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.2259e-04 - mean_absolute_error: 0.0283 - val_loss: 0.0031 - val_mean_absolute_error: 0.0595
# Epoch 163/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.8429e-04 - mean_absolute_error: 0.0285 - val_loss: 0.0032 - val_mean_absolute_error: 0.0598
# Epoch 164/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.7495e-04 - mean_absolute_error: 0.0273 - val_loss: 0.0031 - val_mean_absolute_error: 0.0602
# Epoch 165/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.0936e-04 - mean_absolute_error: 0.0296 - val_loss: 0.0032 - val_mean_absolute_error: 0.0619
# Epoch 166/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.1316e-04 - mean_absolute_error: 0.0285 - val_loss: 0.0035 - val_mean_absolute_error: 0.0647
# Epoch 167/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.5629e-04 - mean_absolute_error: 0.0285 - val_loss: 0.0037 - val_mean_absolute_error: 0.0672
# Epoch 168/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0305 - val_loss: 0.0035 - val_mean_absolute_error: 0.0653
# Epoch 169/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0300 - val_loss: 0.0033 - val_mean_absolute_error: 0.0629
# Epoch 170/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.8751e-04 - mean_absolute_error: 0.0297 - val_loss: 0.0031 - val_mean_absolute_error: 0.0612
# Epoch 171/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.1996e-04 - mean_absolute_error: 0.0290 - val_loss: 0.0032 - val_mean_absolute_error: 0.0621
# Epoch 172/250
# 1822/1822 [==============================] - 5s 2ms/step - loss: 8.8976e-04 - mean_absolute_error: 0.0278 - val_loss: 0.0030 - val_mean_absolute_error: 0.0597
# Epoch 173/250
# 1822/1822 [==============================] - 5s 2ms/step - loss: 8.6082e-04 - mean_absolute_error: 0.0274 - val_loss: 0.0030 - val_mean_absolute_error: 0.0588
# Epoch 174/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.5730e-04 - mean_absolute_error: 0.0272 - val_loss: 0.0030 - val_mean_absolute_error: 0.0600
# Epoch 175/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.6705e-04 - mean_absolute_error: 0.0276 - val_loss: 0.0031 - val_mean_absolute_error: 0.0606
# Epoch 176/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.8838e-04 - mean_absolute_error: 0.0280 - val_loss: 0.0031 - val_mean_absolute_error: 0.0605
# Epoch 177/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.8789e-04 - mean_absolute_error: 0.0288 - val_loss: 0.0032 - val_mean_absolute_error: 0.0596
# Epoch 178/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.4976e-04 - mean_absolute_error: 0.0307 - val_loss: 0.0031 - val_mean_absolute_error: 0.0591
# Epoch 179/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.6220e-04 - mean_absolute_error: 0.0286 - val_loss: 0.0033 - val_mean_absolute_error: 0.0607
# Epoch 180/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.6612e-04 - mean_absolute_error: 0.0315 - val_loss: 0.0037 - val_mean_absolute_error: 0.0653
# Epoch 181/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.2033e-04 - mean_absolute_error: 0.0295 - val_loss: 0.0036 - val_mean_absolute_error: 0.0637
# Epoch 182/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.0162e-04 - mean_absolute_error: 0.0290 - val_loss: 0.0033 - val_mean_absolute_error: 0.0603
# Epoch 183/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.7871e-04 - mean_absolute_error: 0.0280 - val_loss: 0.0030 - val_mean_absolute_error: 0.0580
# Epoch 184/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.4272e-04 - mean_absolute_error: 0.0320 - val_loss: 0.0029 - val_mean_absolute_error: 0.0573
# Epoch 185/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.2986e-04 - mean_absolute_error: 0.0309 - val_loss: 0.0031 - val_mean_absolute_error: 0.0582
# Epoch 186/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.8249e-04 - mean_absolute_error: 0.0280 - val_loss: 0.0031 - val_mean_absolute_error: 0.0583
# Epoch 187/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 8.8619e-04 - mean_absolute_error: 0.0294 - val_loss: 0.0029 - val_mean_absolute_error: 0.0572
# Epoch 188/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.5989e-04 - mean_absolute_error: 0.0287 - val_loss: 0.0029 - val_mean_absolute_error: 0.0569
# Epoch 189/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.5830e-04 - mean_absolute_error: 0.0290 - val_loss: 0.0033 - val_mean_absolute_error: 0.0604
# Epoch 190/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.1416e-04 - mean_absolute_error: 0.0290 - val_loss: 0.0029 - val_mean_absolute_error: 0.0570
# Epoch 191/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.1433e-04 - mean_absolute_error: 0.0265 - val_loss: 0.0035 - val_mean_absolute_error: 0.0625
# Epoch 192/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.1163e-04 - mean_absolute_error: 0.0283 - val_loss: 0.0030 - val_mean_absolute_error: 0.0581
# Epoch 193/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.3701e-04 - mean_absolute_error: 0.0266 - val_loss: 0.0032 - val_mean_absolute_error: 0.0593
# Epoch 194/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.5342e-04 - mean_absolute_error: 0.0270 - val_loss: 0.0030 - val_mean_absolute_error: 0.0581
# Epoch 195/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.4206e-04 - mean_absolute_error: 0.0269 - val_loss: 0.0029 - val_mean_absolute_error: 0.0569
# Epoch 196/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.0111e-04 - mean_absolute_error: 0.0261 - val_loss: 0.0031 - val_mean_absolute_error: 0.0582
# Epoch 197/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.3218e-04 - mean_absolute_error: 0.0276 - val_loss: 0.0030 - val_mean_absolute_error: 0.0573
# Epoch 198/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.9738e-04 - mean_absolute_error: 0.0263 - val_loss: 0.0029 - val_mean_absolute_error: 0.0568
# Epoch 199/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.0915e-04 - mean_absolute_error: 0.0267 - val_loss: 0.0028 - val_mean_absolute_error: 0.0565
# Epoch 200/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.1871e-04 - mean_absolute_error: 0.0267 - val_loss: 0.0028 - val_mean_absolute_error: 0.0560
# Epoch 201/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.3737e-04 - mean_absolute_error: 0.0281 - val_loss: 0.0028 - val_mean_absolute_error: 0.0571
# Epoch 202/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.0778e-04 - mean_absolute_error: 0.0268 - val_loss: 0.0030 - val_mean_absolute_error: 0.0599
# Epoch 203/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.9949e-04 - mean_absolute_error: 0.0304 - val_loss: 0.0031 - val_mean_absolute_error: 0.0612
# Epoch 204/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0310 - val_loss: 0.0030 - val_mean_absolute_error: 0.0600
# Epoch 205/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.7659e-04 - mean_absolute_error: 0.0280 - val_loss: 0.0028 - val_mean_absolute_error: 0.0580
# Epoch 206/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.9623e-04 - mean_absolute_error: 0.0259 - val_loss: 0.0027 - val_mean_absolute_error: 0.0556
# Epoch 207/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.8764e-04 - mean_absolute_error: 0.0264 - val_loss: 0.0028 - val_mean_absolute_error: 0.0561
# Epoch 208/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.9557e-04 - mean_absolute_error: 0.0263 - val_loss: 0.0030 - val_mean_absolute_error: 0.0574
# Epoch 209/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.2241e-04 - mean_absolute_error: 0.0270 - val_loss: 0.0030 - val_mean_absolute_error: 0.0580
# Epoch 210/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.1461e-04 - mean_absolute_error: 0.0273 - val_loss: 0.0027 - val_mean_absolute_error: 0.0554
# Epoch 211/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.1548e-04 - mean_absolute_error: 0.0282 - val_loss: 0.0027 - val_mean_absolute_error: 0.0553
# Epoch 212/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.9508e-04 - mean_absolute_error: 0.0269 - val_loss: 0.0027 - val_mean_absolute_error: 0.0553
# Epoch 213/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 7.8957e-04 - mean_absolute_error: 0.0268 - val_loss: 0.0027 - val_mean_absolute_error: 0.0550
# Epoch 214/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.4076e-04 - mean_absolute_error: 0.0301 - val_loss: 0.0030 - val_mean_absolute_error: 0.0572
# Epoch 215/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.2451e-04 - mean_absolute_error: 0.0281 - val_loss: 0.0029 - val_mean_absolute_error: 0.0568
# Epoch 216/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.9000e-04 - mean_absolute_error: 0.0256 - val_loss: 0.0027 - val_mean_absolute_error: 0.0549
# Epoch 217/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.9000e-04 - mean_absolute_error: 0.0263 - val_loss: 0.0029 - val_mean_absolute_error: 0.0564
# Epoch 218/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.9686e-04 - mean_absolute_error: 0.0260 - val_loss: 0.0029 - val_mean_absolute_error: 0.0569
# Epoch 219/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.1282e-04 - mean_absolute_error: 0.0266 - val_loss: 0.0027 - val_mean_absolute_error: 0.0561
# Epoch 220/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 9.2123e-04 - mean_absolute_error: 0.0281 - val_loss: 0.0027 - val_mean_absolute_error: 0.0558
# Epoch 221/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.2742e-04 - mean_absolute_error: 0.0274 - val_loss: 0.0028 - val_mean_absolute_error: 0.0576
# Epoch 222/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.0580e-04 - mean_absolute_error: 0.0274 - val_loss: 0.0027 - val_mean_absolute_error: 0.0571
# Epoch 223/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.8957e-04 - mean_absolute_error: 0.0282 - val_loss: 0.0032 - val_mean_absolute_error: 0.0625
# Epoch 224/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.3455e-04 - mean_absolute_error: 0.0268 - val_loss: 0.0028 - val_mean_absolute_error: 0.0574
# Epoch 225/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.0275e-04 - mean_absolute_error: 0.0264 - val_loss: 0.0026 - val_mean_absolute_error: 0.0557
# Epoch 226/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.4360e-04 - mean_absolute_error: 0.0296 - val_loss: 0.0026 - val_mean_absolute_error: 0.0551
# Epoch 227/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.2660e-04 - mean_absolute_error: 0.0297 - val_loss: 0.0027 - val_mean_absolute_error: 0.0552
# Epoch 228/250
# 1822/1822 [==============================] - 6s 3ms/step - loss: 8.9962e-04 - mean_absolute_error: 0.0317 - val_loss: 0.0030 - val_mean_absolute_error: 0.0568
# Epoch 229/250
# 1822/1822 [==============================] - 5s 2ms/step - loss: 8.6948e-04 - mean_absolute_error: 0.0306 - val_loss: 0.0026 - val_mean_absolute_error: 0.0557
# Epoch 230/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.4218e-04 - mean_absolute_error: 0.0302 - val_loss: 0.0027 - val_mean_absolute_error: 0.0560
# Epoch 231/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.3049e-04 - mean_absolute_error: 0.0292 - val_loss: 0.0027 - val_mean_absolute_error: 0.0563
# Epoch 232/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.9966e-04 - mean_absolute_error: 0.0268 - val_loss: 0.0026 - val_mean_absolute_error: 0.0543
# Epoch 233/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.0476e-04 - mean_absolute_error: 0.0283 - val_loss: 0.0026 - val_mean_absolute_error: 0.0553
# Epoch 234/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.7588e-04 - mean_absolute_error: 0.0267 - val_loss: 0.0026 - val_mean_absolute_error: 0.0549
# Epoch 235/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.5741e-04 - mean_absolute_error: 0.0263 - val_loss: 0.0026 - val_mean_absolute_error: 0.0540
# Epoch 236/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.4699e-04 - mean_absolute_error: 0.0248 - val_loss: 0.0025 - val_mean_absolute_error: 0.0538
# Epoch 237/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.9108e-04 - mean_absolute_error: 0.0281 - val_loss: 0.0025 - val_mean_absolute_error: 0.0539
# Epoch 238/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.8131e-04 - mean_absolute_error: 0.0277 - val_loss: 0.0026 - val_mean_absolute_error: 0.0538
# Epoch 239/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.6030e-04 - mean_absolute_error: 0.0270 - val_loss: 0.0025 - val_mean_absolute_error: 0.0537
# Epoch 240/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 8.1735e-04 - mean_absolute_error: 0.0280 - val_loss: 0.0025 - val_mean_absolute_error: 0.0542
# Epoch 241/250
# 1822/1822 [==============================] - 5s 2ms/step - loss: 7.5730e-04 - mean_absolute_error: 0.0266 - val_loss: 0.0025 - val_mean_absolute_error: 0.0535
# Epoch 242/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 7.4617e-04 - mean_absolute_error: 0.0254 - val_loss: 0.0026 - val_mean_absolute_error: 0.0535
# Epoch 243/250
# 1822/1822 [==============================] - 5s 3ms/step - loss: 7.2957e-04 - mean_absolute_error: 0.0248 - val_loss: 0.0029 - val_mean_absolute_error: 0.0567
# Epoch 244/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.9619e-04 - mean_absolute_error: 0.0260 - val_loss: 0.0030 - val_mean_absolute_error: 0.0569
# Epoch 245/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.7935e-04 - mean_absolute_error: 0.0264 - val_loss: 0.0028 - val_mean_absolute_error: 0.0550
# Epoch 246/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.3620e-04 - mean_absolute_error: 0.0250 - val_loss: 0.0026 - val_mean_absolute_error: 0.0538
# Epoch 247/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.3170e-04 - mean_absolute_error: 0.0248 - val_loss: 0.0026 - val_mean_absolute_error: 0.0538
# Epoch 248/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.2000e-04 - mean_absolute_error: 0.0244 - val_loss: 0.0028 - val_mean_absolute_error: 0.0552
# Epoch 249/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.4368e-04 - mean_absolute_error: 0.0256 - val_loss: 0.0025 - val_mean_absolute_error: 0.0530
# Epoch 250/250
# 1822/1822 [==============================] - 4s 2ms/step - loss: 7.1577e-04 - mean_absolute_error: 0.0244 - val_loss: 0.0026 - val_mean_absolute_error: 0.0534

# %% [markdown]
# Once we predict the values, we also must *reverse* the normalization so that we can plot the predictions in the same scale as the original values.

# %%
y_pred_train_keras = scaler.inverse_transform(keras_model.predict(X_train_reshape, batch_size=256))
y_pred_keras = scaler.inverse_transform(keras_model.predict(X_test_reshape, batch_size=256))

# %% [markdown]
# Let's now plot what the training and test predictions look like and compare witht he original values.

# %%
# Plot what it looks like for the training data
df_keras = df.copy()
df_keras.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_keras = df_keras.iloc[window_size:ind_split] # Past 32 days we don't know yet
df_keras['Adj Close Train'] = y_pred_train_keras[:-window_size]
df_keras.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# Again, quite accurate... and now for the test data.

# %%
# Same for the test
df_keras = df.copy()
df_keras.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_keras = df_keras.iloc[ind_split+window_size:] # Past 32 days we don't know yet
df_keras['Adj Close Test'] = y_pred_keras
df_keras.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# I have more confidence in the neural network approach as it seems to indicate would the trend would be like when the data is noise free.  We can also see a more smoother transition between points of high curvature.
#
# Finally to see how everything performs, let's plot all of the methods together for both the training and testing data.

# %%
df_train = df.copy()
df_train.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_train = df_train.iloc[window_size:ind_split] # Past 32 days we don't know yet
# Add in all of our methods
df_train['Adj Close Train Ridge'] = y_pred_train_ridge[:-window_size]
df_train['Adj Close Train Gradient Boosting'] = y_pred_train_gb[:-window_size]
df_train['Adj Close Train LSTM'] = y_pred_train_keras[:-window_size]
# Plot the data now
df_train.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# Cool.  They all more or less follow the same trend... and now for the testing data.

# %%
df_test = df.copy()
df_test.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_test = df_test.iloc[ind_split+window_size:] # Past 32 days we don't know yet
# Add in all of our methods
df_test['Adj Close Test Ridge'] = y_pred_ridge
df_test['Adj Close Test Gradient Boosting'] = y_pred_gb
df_test['Adj Close Test LSTM'] = y_pred_keras
# Plot the data now
df_test.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# So here's where it gets interesting.  We can see that the neural network based method is what the values would be when there's no presence of noise.  The ridge regression based method seems to follow the trend the best with the noise modelled in.  The gradient boosting method also follows the same trend, but because the method does not use interpolation, points of very high curvature tend to be the most inaccurate.

# %% [markdown]
# # So what happens if we don't have testing data to try out?
#
# Good question.  What you can do take the learned model that you have, then start with the last $N$ values in your data (in my case 32), and start predicting what the next values will be.  With the next values, keep using the previous $N$ values for your desired forecasting.
#
# We already have our learned models above, so let's go ahead and do that.

# %%
num_days = 10 # Let's try and forecase the next 10 days or two years

# Get the last window_size (32) days
data_seed = df['Adj Close'].values[-window_size:][None]
# Get the normalized data as well for the neural network
data_seed_norm = scaler.transform(data_seed)
input_values = {"ridge": data_seed, "gb": data_seed, "keras": data_seed_norm.copy()}
values = {"ridge": [], "gb": [], "keras": []}
for i in range(num_days): # For each day...
    # Predict the next price given the previous N prices
    values["ridge"].append(ridge_model.predict(input_values["ridge"])[0])
    values["gb"].append(gb_model.predict(input_values["gb"])[0])
    values["keras"].append(keras_model.predict(input_values["keras"][...,None])[0][0])

    # Dump the oldest price and put the newest price at the end
    for v in input_values:
        val = input_values[v]
        val = np.insert(val, -1, values[v][-1], axis=1)
        val = np.delete(val, 0, axis=1)
        input_values[v] = val.copy()

# Convert all to NumPy arrays
for v in input_values:
    values[v] = np.array(values[v])

# Unnormalize prices from NN approach
values["keras"] = scaler.inverse_transform(values["keras"][None])[0]

# %% [markdown]
# Now let's plot the next 10 days worth of data

# %%
from datetime import timedelta, datetime
last_date = datetime.strptime(df.index[-1], '%Y-%m-%d')
df_forecast = pd.DataFrame()
df_forecast["Ridge"] = values["ridge"]
df_forecast["Gradient Boosting"] = values["gb"]
df_forecast["Keras LSTM"] = values["keras"]
df_forecast.index = pd.date_range(start=last_date, periods=num_days)
df_forecast.plot(label='TSLA', figsize=(16,8), title='Forecasted Adjusted Closing Price', grid=True)

# %% [markdown]
# # That's all folks!
#
# ![That's all folks!](https://media.giphy.com/media/l2R0eYcNq9rJUsVAA/giphy.gif)
